# %%
import pandas as pd

output0 = pd.read_pickle('/media/mbiadmin/HDD/DataOutput/experiments/classification/roicnn/new_bg/test/pred_0_df.pickle')

# %%
pd.read_pickle('/media/mbiadmin/HDD/DataOutput/experiments/classification/roicnn/new_bg/test/pred_0_df.pickle')
# Out:
#          pred         pid
# 0    0.519347   HDA133631
# 1    0.524318   HDA236963
# 2    0.524409   HDA309161
# 3    0.512327    HDA36093
# 4    0.520063   HDA384165
# 5    0.523273   HDA393697
# 6    0.524351   HDA470011
# 7    0.524954   HDA489522
# 8    0.515620   HDA496692
# 9    0.511855   HDA497525
# 10   0.510552   HDA498303
# 11   0.512595   HDA498826
# 12   0.511069   HDA500385
# 13   0.511749   HDA500651
# 14   0.524062   HDA500921
# 15   0.503657   HDA500934
# 16   0.519420   HDA502683
# 17   0.521864   HDA503219
# 18   0.510925   HDA504575
# 19   0.516396   HDA504581
# 20   0.524305   HDA505026
# 21   0.525048   HDA505238
# 22   0.523452   HDA505243
# 23   0.513294   HDA505249
# 24   0.523274   HDA513490
# 25   0.520397    HDA64928
# 26   0.524970   MAN187471
# 27   0.524786   MAN192331
# 28   0.525194   MAN192605
# 29   0.526523   MAN193156
# ..        ...         ...
# 168  0.759072   HDA506017
# 169  0.585850   HDA507181
# 170  0.620216   HDA507838
# ...

# %%
print(output0['pred'])
# Out:
# 0      0.519347
# 1      0.524318
# 2      0.524409
# 3      0.512327
# 4      0.520063
# 5      0.523273
# 6      0.524351
# 7      0.524954
# 8      0.515620
# 9      0.511855
# 10     0.510552
# 11     0.512595
# 12     0.511069
# 13     0.511749
# 14     0.524062
# 15     0.503657
# 16     0.519420
# 17     0.521864
# 18     0.510925
# 19     0.516396
# 20     0.524305
# 21     0.525048
# 22     0.523452
# 23     0.513294
# 24     0.523274
# 25     0.520397
# 26     0.524970
# 27     0.524786
# 28     0.525194
# 29     0.526523
#          ...
# 168    0.759072
# 169    0.585850
# 170    0.620216
# 171    0.633786
# 172    0.867897
# 173    0.801806
# 174    0.574186
# 175    0.654225
# 176    0.985942
# 177    0.976030
# 178    0.997336
# 179    0.969262
# 180    0.915471
# 181    0.927069
# 182    0.635735
# 183    0.959877
# 184    0.944001
# 185    0.555198
# 186    0.570005
# 187    0.988824
# 188    0.951549
# 189    0.535946
# 190    0.532100
# 191    0.697999
# ...

# %%
info_df = pd.read_pickle('/media/mbiadmin/HDD/DataOutput/pp_data/dwi_gt_nilearn_final/z_crop/info_df.pickle')

merged =info_df.merge(output0, left_on='pid', right_on='pid', how='inner')

merged['pid', 'patient_label', 'pred']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('pid', 'patient_label', 'pred')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-90133ad8f9cc> in <module>()
# ...

# %%
info_df.merge(output0, left_on='pid', right_on='pid', how='inner')
# Out:
#             pid patient_label breast_label             img  \
# 0    MAN2434524             1         None  MAN2434524.npy
# 1    MAN2453474             1         None  MAN2453474.npy
# 2     MAN194997             1         None   MAN194997.npy
# 3     HDA498301             1         None   HDA498301.npy
# 4     HDA302354             0         None   HDA302354.npy
# 5     HDA384165             0         None   HDA384165.npy
# 6     HDA499568             1         None   HDA499568.npy
# 7     HDA236963             0         None   HDA236963.npy
# 8     HDA393697             1         None   HDA393697.npy
# 9     MAN195941             0         None   MAN195941.npy
# 10    HDA498060             1         None   HDA498060.npy
# 11    HDA497795             1         None   HDA497795.npy
# 12    MAN193156             1         None   MAN193156.npy
# 13      HDA7525             0         None     HDA7525.npy
# 14    HDA394345             0         None   HDA394345.npy
# ...
